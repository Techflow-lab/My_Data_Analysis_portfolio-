# %%
import re

random_text = '''
My name is Mr. Freberg. My phone number is 542-234-2819. My email is AlexFreberg@gmail.com
My name is Mr. Max. My phone number is 413-234-2568. My emails is RoughRuff@yahoo.com.
My name is Mrs. Rosie. My phone number is 285-036-8215. My emails is GoldenGirl@apple.com.
'''

# %%
re.findall(r'@(\w+).com', random_text)
# Out:
# ['gmail', 'yahoo', 'apple']

# %%
re.findall(r'\d{3}-\d{3}-\d{4}', random_text)
# Out:
# ['542-234-2819', '413-234-2568', '285-036-8215']

# %%
email_list = re.findall(r' (\w+@\w+.com)', random_text)
email_list
# Out:
# ['AlexFreberg@gmail.com', 'RoughRuff@yahoo.com', 'GoldenGirl@apple.com']

# %%
domain_list = [re.findall(r'^(\w+)@', email)[0] for email in email_list]
domain_list
# Out:
# ['AlexFreberg', 'RoughRuff', 'GoldenGirl']

# %%
capital = [re.findall(r'[A-Z]',domain) for domain in domain_list ]
capital
# Out:
# [['A', 'F'], ['R', 'R'], ['G', 'G']]

# %%
import re

# List of Phone Numbers
phone_numbers = ["(123) 456-7890", "(555) 123-4567", "(987) 654-3210", "(800) 555-1212", "(123) 456-7890"]

area_code_pattern = r''

# List to store extracted area codes:
area_codes = []

# Loop through each phone number and extract area codes:


# Print out the list:
print(area_codes)
# Out:
# []

# %%
import re

# List of Phone Numbers
phone_numbers = ["(123) 456-7890", "(555) 123-4567", "(987) 654-3210", "(800) 555-1212", "(123) 456-7890"]

area_code_pattern = r'\((\d{3})\)'

# List to store extracted area codes:
area_codes = []

# Loop through each phone number and extract area codes:
for phone_number in phone_numbers:
    match = re.search(area_code_pattern, phone_number)
    if match:
        area_codes.append(match.group(1))

# Print out the list:
print(area_codes)
# Out:
# ['123', '555', '987', '800', '123']
