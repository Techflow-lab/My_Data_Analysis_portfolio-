# %%
# Pandas Series and DataFrame concept()
import numpy as np
import pandas as pd

# %%
my_list = [123, 234, 345]
x = np.array(my_list)
x
# Out:
# array([123, 234, 345])

# %%
type(x)
# Out:
# numpy.ndarray

# %%
y = pd.Series(my_list)
# Out:
# 0    123
# 1    234
# 2    345
# dtype: int64

# %%
index_value = ['high', 'middle', 'low']
one = pd.Series(data = my_list, index = index_value)
one
# Out:
# high      123
# middle    234
# low       345
# dtype: int64

# %%
index_value1 = ['first', 'second', 'third']
two = pd.Series(data = my_list, index = index_value1)
two
# Out:
# first     123
# second    234
# third     345
# dtype: int64

# %%
ice_cream = [['mango',1],['apple',2],['strawberry',3]]
pd.DataFrame(data = ice_cream, index = ['good', 'ok', 'plain'], columns = ['name','score'])
# Out:
#              name  score
# good        mango      1
# ok          apple      2
# plain  strawberry      3

# %%
# Read file
pd.read_csv(r"url", columns = ['name1', 'name2', 'name3'],)
pd.read_excel()
pd.read_json()
